# %% [markdown]
# # Data parsing

# %%
using PyPlot: pygui
pygui(true)
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
using SparseArrays
using LightGraphs

include("Parsers.jl")
include("Resolution.jl")
include("plot.jl")
# Out:
# plot_bus_stops

# %%
include("Algo_en_ligne.jl")
# Out:
# algo_pseudo_en_ligne (generic function with 3 methods)

# %%
file_directory = "/Users/alicekrychowskimac/Documents/Ponts/2A/Padam/Padam_Project/Data/Instance Padam"
client_file_name = joinpath(file_directory, "customer_requests.csv")
driver_file_name = joinpath(file_directory, "driver_shifts.csv")
map_file_name = joinpath(file_directory, "mTSP_matrix.csv")
gamma_file_name = joinpath(file_directory, "gammas.csv")
node_coordinates_file_name = joinpath(file_directory, "node_coordinates.csv")
# Out:
# "/Users/alicekrychowskimac/Documents/Ponts/2A/Padam/Padam_Project/Data/Instance Padam/node_coordinates.csv"

# %%
solution = algo_pseudo_en_ligne(file_directory)
# Out:
# Importation des données...
# Fin de l'importation des données.
# Person[Person(203, 25200.0, 28800.0), Person(207, 21600.0, 28800.0), Person(202, 23400.0, 28800.0)]
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-05-21
# Client 2
# fast instertion false
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-05-21
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-05-21
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-05-21
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# ...

# %%
loc = build_localisations(node_coordinates_file_name)
depots, gare = build_drivers_and_gare(driver_file_name)
# Out:
# (Person[Person(207, 21600.0, 28800.0), Person(207, 21600.0, 28800.0), Person(207, 21600.0, 28800.0), Person(207, 21600.0, 28800.0), Person(207, 21600.0, 28800.0), Person(203, 25200.0, 28800.0), Person(203, 25200.0, 28800.0), Person(203, 25200.0, 28800.0), Person(202, 23400.0, 28800.0), Person(202, 23400.0, 28800.0), Person(202, 23400.0, 28800.0)], Person(207, 28800.0, 28800.0))

# %%
pl = plot_bus_stops(loc, depots, gare)

# %%
p_test_cluster = plot_clusters(solution, loc, pl, false)

# %%
people = build_people_real_file_only_client(client_file_name, driver_file_name, map_file_name, gamma_file_name, false)
# Out:
# 200-element Array{Any,1}:
#  Person(204, 27227.5, 28800.0)
#  Person(11, 27151.0, 28800.0)
#  Person(201, 26785.5, 28800.0)
#  Person(84, 26559.4, 28800.0)
#  Person(53, 26389.4, 28800.0)
#  Person(171, 27506.3, 28800.0)
#  Person(193, 26511.8, 28800.0)
#  Person(199, 27108.5, 28800.0)
#  Person(25, 27725.6, 28800.0)
#  Person(145, 26911.3, 28800.0)
#  Person(47, 26216.0, 28800.0)
#  Person(135, 28040.2, 28800.0)
#  Person(36, 27533.5, 28800.0)
#  ⋮
#  Person(120, 27137.4, 28800.0)
#  Person(124, 26729.4, 28800.0)
#  Person(7, 27125.5, 28800.0)
#  Person(53, 26389.4, 28800.0)
#  Person(173, 27317.6, 28800.0)
#  Person(122, 27293.8, 28800.0)
#  Person(143, 26981.0, 28800.0)
#  Person(29, 27455.3, 28800.0)
#  Person(129, 26957.2, 28800.0)
#  Person(140, 26573.0, 28800.0)
#  Person(71, 27190.1, 28800.0)
#  Person(26, 27771.5, 28800.0)

# %%
length_max = 40
gare_type_pers = Person(start_point = gare, start_time = 0.0, end_time = 28800.0)
# Out:
# Person(207, 0.0, 28800.0)

# %%
map,n = parser_real_file(map_file_name)
# Out:
# (
#   [2  ,   1]  =  371.0
#   [3  ,   1]  =  580.0
#   [4  ,   1]  =  429.0
#   [5  ,   1]  =  569.0
#   [6  ,   1]  =  415.0
#   [7  ,   1]  =  337.0
#   [8  ,   1]  =  651.0
#   [9  ,   1]  =  603.0
#   [10 ,   1]  =  791.0
#   [11 ,   1]  =  595.0
#   [12 ,   1]  =  973.0
#   [13 ,   1]  =  960.0
#   ⋮
#   [204, 217]  =  507.0
#   [205, 217]  =  93.0
#   [206, 217]  =  590.0
#   [207, 217]  =  904.0
#   [208, 217]  =  1224.0
#   [209, 217]  =  584.0
#   [210, 217]  =  302.0
#   [211, 217]  =  397.0
#   [212, 217]  =  437.0
#   [213, 217]  =  331.0
#   [214, 217]  =  178.0
#   [215, 217]  =  1417.0
#   [216, 217]  =  1431.0, 217)

# %%
sol_creation_cluster = creation_cluster(people, gare_type_pers, depots, map, 100)
# Out:
# Academic license - for non-commercial use only - expires 2021-05-21
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 275 rows, 132 columns and 724 nonzeros
# Model fingerprint: 0x00a7e4a7
# Variable types: 11 continuous, 121 integer (121 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 3e+04]
# Found heuristic solution: objective 299014.50000
# Presolve removed 85 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 190 rows, 84 columns, 563 nonzeros
# Variable types: 11 continuous, 73 integer (73 binary)
#
# Root relaxation: objective 3.153590e+05, 37 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...

# %%
p_creation_cluster = plot_clusters(sol_creation_cluster, loc, pl)
# Out:
# UndefVarError: sol_creation_cluster not defined
#
# Stacktrace:
#  [1] top-level scope at In[19]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
sol_hierarchical_clustering = hierarchical_clustering(people, map, gare_type_pers, depots, length_max)
# Out:
# Academic license - for non-commercial use only - expires 2021-05-21
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 44 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x2900c8db
# Variable types: 4 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+02, 3e+04]
# Found heuristic solution: objective 107604.80000
# Presolve removed 33 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 7 columns, 33 nonzeros
# Found heuristic solution: objective 108259.40000
# Variable types: 4 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 1.137410e+05, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# ...

# %%
p_hierarchical_clustering = plot_clusters(sol_hierarchical_clustering, loc, pl)

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[1], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[2], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[3], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[4], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[5], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[6], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[7], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[8], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[9], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[10], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[11], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[12], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[13], loc, pl_test )

# %%
pl_test = plot_bus_stops(loc, depots, gare)
pl_clust_1 = add_cluster_to_plot!(sol_hierarchical_clustering.clusters[14], loc, pl_test )

# %%
len(hier)
# Out:
# BoundsError: attempt to access 14-element Array{Cluster,1} at index [24]
#
# Stacktrace:
#  [1] getindex(::Array{Cluster,1}, ::Int64) at ./array.jl:809
#  [2] top-level scope at In[39]:2
#  [3] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
